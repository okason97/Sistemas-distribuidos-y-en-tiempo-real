# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
ccsv = pd.read_csv("csock/time.csv")
jcsv = pd.read_csv("javasock/time.csv")

# %%
jcsv['time'] = jcsv['time'].apply(lambda x: x/1_000_000_000)

# %%
ccsv['key'] = "c";
jcsv['key'] = "java";

# %%
DF = pd.concat([ccsv,jcsv], sort=False)
DF
# Out:
#      type      time   key
# 0   write  0.000257     c
# 1   write  0.000256     c
# 2   write  0.000244     c
# 3   write  0.000286     c
# 4   write  0.000107     c
# 5   write  0.000248     c
# 6   write  0.000274     c
# 7   write  0.000258     c
# 8   write  0.000247     c
# 9   write  0.000242     c
# 10  write  0.000242     c
# 0    time  0.000088  java
# 1    time  0.000106  java
# 2    time  0.000092  java
# 3    time  0.000353  java
# 4    time  0.000076  java
# 5    time  0.000117  java
# 6    time  0.000086  java
# 7    time  0.000098  java
# 8    time  0.000090  java
# 9    time  0.000087  java
# 10   time  0.000099  java
# 11   time  0.000123  java
# 12   time  0.000077  java
# 13   time  0.000095  java
# 14   time  0.000088  java
# 15   time  0.000094  java
# 16   time  0.000092  java
# 17   time  0.000091  java
# 18   time  0.000090  java
# 19   time  0.000100  java
# 20   time  0.000088  java
# 21   time  0.000098  java
# 22   time  0.000050  java
# 23   time  0.000093  java

# %%
DF.groupby(['key']).mean().unstack().plot.bar()

# %%
DF.groupby(['key']).std().unstack().plot.bar()
